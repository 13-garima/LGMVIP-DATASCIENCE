# %% [markdown]
# # LGM VIP AUGUST 20222
# # DATA ANALYTICS
# # TASK 1 : Machine Learning on IRIS data set

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read file and  get first 5 rows

# %%
df = pd.read_csv("iris.csv")
# print(df.to_string()) prints entire data set
# we will see the first 5 rows
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# # The last 5 rows

# %%
df.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# # Rename the columns in data frame
# ## The data set attribute information is given as
# 1. sepal length in cm
#
# 2. sepal width in cm
#
# 3. petal length in cm
#
# 4. petal width in cm
#
# 5. class
#
# ### Using set_axis  method the column name can be changed as below code:

# %%
df.set_axis(['sepal length', 'sepal width', 'petal length','petal width ','class'], axis='columns', inplace=True)
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width         class
# 0           4.9          3.0           1.4           0.2  Iris-setosa
# 1           4.7          3.2           1.3           0.2  Iris-setosa
# 2           4.6          3.1           1.5           0.2  Iris-setosa
# 3           5.0          3.6           1.4           0.2  Iris-setosa
# 4           5.4          3.9           1.7           0.4  Iris-setosa

# %% [markdown]
# # Analysis of data set using pandas

# %% [markdown]
# ## Information in  a df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  149 non-null    float64
#  1   sepal width   149 non-null    float64
#  2   petal length  149 non-null    float64
#  3   petal width   149 non-null    float64
#  4   class         149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ## Display Max Rows

# %%
print("Maxium Number of Rows is :",pd.options.display.max_rows)
# Out:
# Maxium Number of Rows is : 60

# %% [markdown]
# # Remove Duplicate

# %%
duplicate = df.drop_duplicates(subset ="class",)
duplicate
# Out:
#     sepal length  sepal width  petal length  petal width             class
# 0            4.9          3.0           1.4           0.2      Iris-setosa
# 49           7.0          3.2           4.7           1.4  Iris-versicolor
# 99           6.3          3.3           6.0           2.5   Iris-virginica

# %% [markdown]
# ## Display columns

# %%
df.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width ', 'class'], dtype='object')

# %% [markdown]
# ## Statistical information of dataset

# %%
describe=pd.DataFrame(df.describe())
describe
# Out:
#        sepal length  sepal width  petal length  petal width
# count    149.000000   149.000000    149.000000    149.000000
# mean       5.848322     3.051007      3.774497      1.205369
# std        0.828594     0.433499      1.759651      0.761292
# min        4.300000     2.000000      1.000000      0.100000
# 25%        5.100000     2.800000      1.600000      0.300000
# 50%        5.800000     3.000000      4.400000      1.300000
# 75%        6.400000     3.300000      5.100000      1.800000
# max        7.900000     4.400000      6.900000      2.500000

# %%
df.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# class           0
# dtype: int64

# %% [markdown]
# ## Result of Analysis
#
# 1) 5 columns, 60 rows
#
# 2) No null values,data type:int64
#
# 3) name of columns changed
#
# 4) Statistical information of all the columns calculated

# %% [markdown]
# ## Machine leaning Tasks

# %% [markdown]
# ## Find Correlations
#
# ### Find Correlations Between Columns

# %%
df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.103784      0.871283      0.816971
# sepal width      -0.103784     1.000000     -0.415218     -0.350733
# petal length      0.871283    -0.415218      1.000000      0.962314
# petal width       0.816971    -0.350733      0.962314      1.000000

# %% [markdown]
# ##  Findings :
# ### Correlations Varies from -1 to 1:
#
# 1) Sepal length and petal width as well as petal length and petal width have good correlation in increasing order.
#
# 2) petal width and sepal width may have correlation in decreasing order.

# %% [markdown]
# ## Ploting

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.hist(edgecolor='blue', linewidth=2.2)
# Out:
# array([[<AxesSubplot:title={'center':'sepal length'}>,
#         <AxesSubplot:title={'center':'sepal width'}>],
#        [<AxesSubplot:title={'center':'petal length'}>,
#         <AxesSubplot:title={'center':'petal width '}>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.pairplot(data=df,hue="class",palette="Set2")
plt.show()

# %% [markdown]
# # KNN model

# %%
x = df.drop("class", axis=1)
y = df["class"]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size=0.2, 
                                                    random_state=0)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
x_new = np.array([[4.9, 2.9, 1, 0.4]])
prediction = knn.predict(x_new)
print("Prediction: {}".format(prediction))
# Out:
# Prediction: ['Iris-setosa']
